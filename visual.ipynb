# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3

sns.set_theme()

# %%
conn = sqlite3.connect("piperlog.db")
df = pd.read_sql_query("SELECT * from Piper", conn)
df
# Out:
#    Month  Day  Year             Food Benadryl  \
# 0     10   17  2020  Rawwble mixture     None
# 1     10   20  2020     Rawwble Lamb     None
#
#                             Outside                     Energy  Poo count  \
# 0          30 - 60 mins in the yard                    Playful          3
# 1  Less than 30 minutes in the yard  Acting weird. Low energy.          3
#
#                                     Poo quality Itching Paws  Bumpiness  \
# 0                                             7            8          3
# 1  Poo Quality (0 bad poo poo - 10 solid dooky)            8          3
#
#   Rawspots Lounge
# 0     None   None
# 1     None   None

# %%
df.describe()
# Out:
#        Month       Day    Year  Poo count  Bumpiness
# count    2.0   2.00000     2.0        2.0        2.0
# mean    10.0  18.50000  2020.0        3.0        3.0
# std      0.0   2.12132     0.0        0.0        0.0
# min     10.0  17.00000  2020.0        3.0        3.0
# 25%     10.0  17.75000  2020.0        3.0        3.0
# 50%     10.0  18.50000  2020.0        3.0        3.0
# 75%     10.0  19.25000  2020.0        3.0        3.0
# max     10.0  20.00000  2020.0        3.0        3.0

# %%
sns.relplot(data = df, x = "Bumpiness", y="Outside")
